# %%
from imageai.Detection import ObjectDetection
import os

execution_path = os.getcwd()

detector = ObjectDetection()
detector.setModelTypeAsRetinaNet()
detector.setModelPath( os.path.join(execution_path , "resnet50_coco_best_v2.0.1.h5"))
detector.loadModel()

for idx in range(3):
    detections = detector.detectObjectsFromImage(
        input_image=os.path.join(execution_path , ("%02d%s" % (idx+1, ".jpg"))), 
        output_image_path=os.path.join(execution_path , ("%02d%s" % (idx+1, "-New.jpg")))
    )
    for eachObject in detections:
        print("Number of Image: %d\n" % (idx+1), end="\t")
        print(eachObject["name"] + " : " + eachObject["percentage_probability"] )
        print()
print("Detection of the End.")
# Out:
# Number of Image: 1
# 	bear : 99.75950717926025
#
# Number of Image: 1
# 	sheep : 92.48863458633423
#
# Number of Image: 1
# 	bear : 58.18139910697937
#
# Number of Image: 2
# 	clock : 96.621572971344
#
# Number of Image: 2
# 	potted plant : 53.40110659599304
#
# Number of Image: 2
# 	person : 55.63291907310486
#
# Number of Image: 2
# 	cup : 64.17721509933472
#
# Number of Image: 2
# 	bowl : 60.75526475906372
#
# Number of Image: 2
# 	cup : 80.93705177307129
#
# Number of Image: 2
# 	person : 79.11202907562256
#
# Number of Image: 2
# 	person : 83.53654742240906
#
# Number of Image: 2
# 	person : 55.75847625732422
#
# Number of Image: 2
# 	person : 77.61064171791077
#
# Number of Image: 2
# 	bowl : 69.24607753753662
#
# Number of Image: 2
# 	person : 57.799720764160156
#
# Number of Image: 2
# 	person : 63.87990713119507
#
# Number of Image: 2
# 	person : 92.17500686645508
#
# Number of Image: 2
# 	person : 88.13974857330322
#
# Number of Image: 2
# 	person : 93.51404905319214
#
# Number of Image: 2
# 	dining table : 64.73408937454224
#
# Number of Image: 3
# 	car : 54.032301902770996
#
# Number of Image: 3
# 	car : 61.47294640541077
#
# Number of Image: 3
# 	person : 57.320016622543335
#
# Number of Image: 3
# 	motorcycle : 55.89889883995056
#
# Number of Image: 3
# 	motorcycle : 50.34119486808777
#
# Number of Image: 3
# 	person : 57.32511281967163
#
# Number of Image: 3
# 	person : 52.88321375846863
#
# Number of Image: 3
# 	bus : 68.43833923339844
#
# Number of Image: 3
# 	car : 66.38975143432617
#
# Number of Image: 3
# 	car : 54.34386730194092
#
# Number of Image: 3
# 	car : 57.007187604904175
#
# Number of Image: 3
# 	car : 71.71570658683777
#
# Number of Image: 3
# 	car : 63.86680603027344
#
# Number of Image: 3
# 	car : 68.7980592250824
#
# Number of Image: 3
# 	car : 57.014596462249756
#
# Number of Image: 3
# 	car : 62.54476308822632
#
# Number of Image: 3
# 	car : 54.06264066696167
#
# Number of Image: 3
# 	car : 64.88337516784668
#
# Number of Image: 3
# 	car : 67.53666400909424
#
# Number of Image: 3
# 	car : 59.420496225357056
#
# Number of Image: 3
# 	car : 59.85921025276184
#
# Number of Image: 3
# 	person : 63.186365365982056
#
# Number of Image: 3
# 	person : 57.01647996902466
#
# Number of Image: 3
# 	car : 75.90939998626709
#
# Number of Image: 3
# 	car : 80.07043600082397
#
# Number of Image: 3
# 	car : 83.85112285614014
#
# Number of Image: 3
# 	car : 81.29413723945618
#
# Number of Image: 3
# 	car : 85.933917760849
#
# Number of Image: 3
# 	car : 96.35610580444336
#
# Number of Image: 3
# 	motorcycle : 55.10096549987793
#
# Number of Image: 3
# 	person : 64.09738063812256
#
# Number of Image: 3
# 	car : 93.02524328231812
#
# Number of Image: 3
# 	car : 95.64579725265503
#
# Number of Image: 3
# 	car : 67.78892874717712
#
# Number of Image: 3
# 	car : 88.82200717926025
#
# Number of Image: 3
# 	car : 97.0680832862854
#
# Number of Image: 3
# 	car : 99.2045521736145
#
# Detection of the End.
